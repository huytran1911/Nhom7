# %% [markdown]
# <font size="5">Nội dung 1: Làm quen với dữ liệu và Matplotlib</font>

# %% [markdown]
# **a.** Tải tập dữ liệu HR_comma_sep.csv và sử dụng pandas để đọc dữ liệu.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Đọc dữ liệu từ tệp CSV
file_path = 'HR_comma_sep.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# **b.** Thực hiện phân tích cơ bản( sử dụng describe(). info()) để hiểu cấu trúc và các đặc điểm của dữ liệu

# %%
print(df.describe())
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# **c.** Sử dụng Matplotlib để vẽ

# %% [markdown]
# Biểu đồ cột (bar plot) thể hiện số lượng nhân viên theo mức lương (salary).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Đọc dữ liệu từ tệp CSV
file_path = 'HR_comma_sep.csv'
df = pd.read_csv(file_path)

# ======= Biểu đồ cột (Bar Plot) =======
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='salary', data=df, hue='salary', palette='viridis', legend=False)

# Hiển thị số lượng trên mỗi cột
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', 
                xytext=(0, 5), textcoords='offset points')

# Thêm tiêu đề và nhãn trục
plt.title('Số lượng nhân viên theo mức lương', fontsize=14)
plt.xlabel('Mức lương', fontsize=12)
plt.ylabel('Số lượng nhân viên', fontsize=12)

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# Biểu đồ phân tán (scatter plot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Đọc dữ liệu từ tệp CSV
file_path = 'HR_comma_sep.csv'
df = pd.read_csv(file_path)

# ======= Biểu đồ phân tán (Scatter Plot) =======
plt.figure(figsize=(8, 5))
sns.scatterplot(x='satisfaction_level', y='last_evaluation', 
                hue='left', data=df, 
                palette={0: 'blue', 1: 'red'}, alpha=0.7)

# Thêm tiêu đề và nhãn trục
plt.title('Mối quan hệ giữa Satisfaction Level và Last Evaluation', fontsize=14)
plt.xlabel('Satisfaction Level', fontsize=12)
plt.ylabel('Last Evaluation', fontsize=12)

# Thêm chú thích
plt.legend(title='Trạng thái nghỉ việc', labels=['Chưa nghỉ việc', 'Đã nghỉ việc'])

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# <font size="5"> Nội dung 2: Trực quan hóa nâng cao với Seaborn </font>

# %% [markdown]
# **a.** Sử dụng Seaborn để vẽ:

# %% [markdown]
# Một lmplot giữa sastisfaction_level và last_evaluation vs hue="left".

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Tải dữ liệu từ file CSV
file_path = 'HR_comma_sep.csv'
data = pd.read_csv(file_path)

# Đặt kiểu hiển thị cho các biểu đồ Seaborn
sns.set(style="whitegrid")

# 1. Tạo biểu đồ lmplot cho satisfaction_level và last_evaluation với hue='left'
plt.figure(figsize=(8, 6))
sns.lmplot(data=data, x='satisfaction_level', y='last_evaluation', hue='left', logistic=True)
plt.title('Mức độ hài lòng và Đánh giá cuối cùng (Phân theo việc nghỉ việc của nhân viên)', fontsize=14)
plt.xlabel('Mức độ hài lòng', fontsize=12)
plt.ylabel('Đánh giá cuối cùng', fontsize=12)
plt.show()

# %% [markdown]
# **Biểu đồ phân tán (scatter plot):**
#
# Mối quan hệ giữa mức độ hài lòng (satisfaction_level) và đánh giá cuối cùng (last_evaluation) cho thấy sự phân chia rõ ràng giữa các nhân viên còn làm việc và các nhân viên đã nghỉ việc.
#
# Các điểm dữ liệu màu xanh (nhân viên còn làm việc) chủ yếu tập trung ở các mức độ hài lòng cao và đánh giá cuối cùng cũng cao.
#
# Các điểm màu cam (nhân viên đã nghỉ việc) chủ yếu tập trung ở các mức độ hài lòng thấp hơn và đánh giá cuối cùng thấp hơn. Điều này cho thấy mối liên hệ giữa mức độ hài lòng thấp và khả năng nghỉ việc cao.

# %% [markdown]
# <br>
#
#
#
# Boxplot so sánh phân phối sastisfaction_level theo mức lương (Salary)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Tải dữ liệu từ file CSV
file_path = 'HR_comma_sep.csv'
data = pd.read_csv(file_path)

# Đặt kiểu hiển thị cho các biểu đồ Seaborn
sns.set(style="whitegrid")

# 2. Tạo biểu đồ boxplot cho mức độ hài lòng theo mức lương
plt.figure(figsize=(8, 6))
sns.boxplot(x='salary', y='satisfaction_level', data=data, hue='salary', palette='muted')
plt.title('Phân phối mức độ hài lòng theo mức lương', fontsize=14)
plt.xlabel('Mức lương', fontsize=12)
plt.ylabel('Mức độ hài lòng', fontsize=12)
plt.show()

# %% [markdown]
# **Biểu đồ boxplot:**
#
# Mức độ hài lòng của nhân viên có lương thấp có xu hướng thấp hơn so với các nhóm nhân viên có lương trung bình hoặc cao.
#
# Các nhân viên có lương cao có mức độ hài lòng cao nhất và phân tán ít hơn, cho thấy rằng mức lương cao có thể liên quan đến mức độ hài lòng ổn định hơn.
#
# Nhân viên có mức lương thấp và trung bình có sự phân tán mức độ hài lòng lớn hơn, có thể cho thấy sự không hài lòng hoặc sự bất mãn trong công việc.

# %% [markdown]
# <br>
#
# Một countplot thể hiện số lượng nhân viên theo salary, phân loại theo left

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Tải dữ liệu từ file CSV
file_path = 'HR_comma_sep.csv'
data = pd.read_csv(file_path)

# Đặt kiểu hiển thị cho các biểu đồ Seaborn
sns.set(style="whitegrid")

# 3. Tạo biểu đồ countplot cho số lượng nhân viên theo mức lương và việc nghỉ việc
plt.figure(figsize=(8, 6))
sns.countplot(x='salary', hue='left', data=data)
plt.title('Số lượng nhân viên theo mức lương và việc nghỉ việc', fontsize=14)
plt.xlabel('Mức lương', fontsize=12)
plt.ylabel('Số lượng nhân viên', fontsize=12)
plt.show()

# %% [markdown]
# **Biểu đồ countplot:**
#
# Nhân viên có lương thấp chiếm số lượng lớn nhất trong tổng số nhân viên, với phần lớn là nhân viên còn làm việc (xanh).
#
# Nhân viên có lương cao có số lượng ít hơn và tỷ lệ nghỉ việc cũng thấp hơn nhiều. Điều này cho thấy mức lương cao có thể giảm khả năng nghỉ việc.
#
# Các nhân viên có mức lương trung bình có sự phân chia khá đều giữa nhân viên còn làm việc và nghỉ việc, điều này có thể chỉ ra rằng mức lương trung bình không có tác động mạnh mẽ đến việc nhân viên nghỉ việc.

# %% [markdown]
# <font size=5>Nội dung 3: Trực quan hóa tương tác với Bokeh </font>

# %% [markdown]
# <font size="5"> Nội dung 4: </font>

# %% [markdown]
# **1.** Mô tả dữ liệu và mục tiêu phân tích

# %% [markdown]
# Tập dữ liệu HR_comma_sep.csv chứa thông tin về nhân viên trong một công ty, bao gồm các đặc điểm như mức độ hài lòng (satisfaction_level), đánh giá cuối cùng (last_evaluation), số giờ làm việc hàng tháng (average_monthly_hours), mức lương (salary), và thông tin liệu nhân viên có nghỉ việc (left) hay không. Tập dữ liệu này có 10 cột và bao gồm 14999 bản ghi nhân viên.
#
# Mục tiêu của phân tích này là khám phá các yếu tố có thể ảnh hưởng đến quyết định nghỉ việc của nhân viên trong công ty. Đặc biệt, chúng ta sẽ nghiên cứu mối quan hệ giữa các yếu tố như mức độ hài lòng, đánh giá cuối cùng, và mức lương với quyết định nghỉ việc (biến left). Các biểu đồ như scatter plot, box plot, và count plot sẽ được sử dụng để trực quan hóa các mối quan hệ giữa các biến trong tập dữ liệu và từ đó rút ra các kết luận về các yếu tố quan trọng tác động đến quyết định nghỉ việc của nhân viên.
#
# Mục tiêu cuối cùng là giúp các bộ phận nhân sự hiểu rõ hơn về các yếu tố ảnh hưởng đến việc giữ chân nhân viên và cải thiện các chính sách quản lý nhân sự để giảm tỷ lệ nghỉ việc.
